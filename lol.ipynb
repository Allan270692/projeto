# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("dados_aids_hiv_excel.xlsx")
df = df.dropna() 
df['NU_IDADE_N'].value_counts().plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
